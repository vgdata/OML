# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.20.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-138268
# aml-quickstarts-138268
# southcentralus
# b968fb36-f06a-4c76-a15f-afab68ae7667

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'ml-experiment-1'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: ml-experiment-1,
# Workspace: quick-starts-ws-138268)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "auto-ml"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Creating
# Succeeded................................................................................................................
# AmlCompute wait for completion finished
#
# Wait timeout has been reached
# Current provisioning state of AmlCompute is "Succeeded" and current node count is "0"

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "BankMarketing Dataset"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [392542a2][2ee00bf9-5db9-4ced-bd58-eb2dbadc1954], (This step will run and generate new outputs)
# Submitted PipelineRun 93edac60-ce6d-4022-95b9-043379e050cb
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/ml-experiment-1/runs/93edac60-ce6d-4022-95b9-043379e050cb?wsid=/subscriptions/b968fb36-f06a-4c76-a15f-afab68ae7667/resourcegroups/aml-quickstarts-138268/workspaces/quick-starts-ws-138268

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: 93edac60-ce6d-4022-95b9-043379e050cb
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/ml-experiment-1/runs/93edac60-ce6d-4022-95b9-043379e050cb?wsid=/subscriptions/b968fb36-f06a-4c76-a15f-afab68ae7667/resourcegroups/aml-quickstarts-138268/workspaces/quick-starts-ws-138268
# PipelineRun Status: Running
#
#
# StepRunId: d4803e95-b194-4cd5-8c7a-43fcf89e1a6b
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/ml-experiment-1/runs/d4803e95-b194-4cd5-8c7a-43fcf89e1a6b?wsid=/subscriptions/b968fb36-f06a-4c76-a15f-afab68ae7667/resourcegroups/aml-quickstarts-138268/workspaces/quick-starts-ws-138268
# StepRun( automl_module ) Status: Running
#
# StepRun(automl_module) Execution Summary
# =========================================
# StepRun( automl_module ) Status: Finished
# {'runId': 'd4803e95-b194-4cd5-8c7a-43fcf89e1a6b', 'target': 'auto-ml', 'status': 'Completed', 'startTimeUtc': '2021-02-09T18:06:23.037769Z', 'endTimeUtc': '2021-02-09T18:46:58.162533Z', 'properties': {'ContentSnapshotId': '8b2f873a-caf9-4953-92dd-7289bdcd7eb0', 'StepType': 'AutoMLStep', 'azureml.moduleid': '2ee00bf9-5db9-4ced-bd58-eb2dbadc1954', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '392542a2', 'azureml.pipelinerunid': '93edac60-ce6d-4022-95b9-043379e050cb', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'AUC_weighted', 'train_split': '0', 'MaxTimeSeconds': None, 'acquisition_parameter': '0', 'num_cross_validation': None, 'target': 'auto-ml', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "b968fb36-f06a-4c76-a15f-afab68ae7667", "resource_group": "aml-quickstarts-138268", "workspace_name": "quick-starts-ws-138268", "region": "southcentralus", "compute_target": "auto-ml", "spark_service": null, "azure_service": null, "many_models": false, "pipeline_fetch_max_batch_size": 1, "iterations": 1000, "primary_metric": "AUC_weighted", "task_type": "classification", "data_script": null, "validation_size": 0.0, "n_cross_validations": null, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": 1, "max_concurrent_iterations": 5, "iteration_timeout_minutes": null, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 20, "experiment_exit_score": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["DecisionTree", "TensorFlowDNN", "RandomForest", "BernoulliNaiveBayes", "ExtremeRandomTrees", "XGBoostClassifier", "MultinomialNaiveBayes", "SVM", "KNN", "LinearSVM", "TensorFlowLinearClassifier", "GradientBoosting", "LogisticRegression", "LightGBM", "SGD", "AveragedPerceptronClassifier"], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "automl_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": false, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_D2_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "scenario": "SDK-1.13.0", "environment_label": null, "force_text_dnn": false, "enable_feature_sweeping": true, "enable_early_stopping": true, "early_stopping_n_iters": 10, "metrics": null, "enable_ensembling": true, "enable_stack_ensembling": true, "ensemble_iterations": 15, "enable_tf": false, "enable_subsampling": null, "subsample_seed": null, "enable_nimbusml": false, "enable_streaming": false, "force_streaming": false, "track_child_runs": true, "allowed_private_models": [], "label_column_name": "y", "weight_column_name": null, "cv_split_column_names": null, "enable_local_managed": false, "_local_managed_run_id": null, "cost_mode": 1, "lag_length": 0, "metric_operation": "maximize", "preprocess": true}', 'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"c72d4aa1-0956-48a0-8b88-591128442bcf\\"}, \\"datasets\\": 0}', 'EnableSubsampling': 'False', 'runTemplate': 'AutoML', 'Orchestrator': 'automl', 'ClientType': 'Others', '_aml_system_scenario_identification': 'Remote.Parent', 'root_attribution': 'azureml.StepRun', 'snapshotId': '8b2f873a-caf9-4953-92dd-7289bdcd7eb0', 'SetupRunId': 'd4803e95-b194-4cd5-8c7a-43fcf89e1a6b_setup', 'SetupRunContainerId': 'dcid.d4803e95-b194-4cd5-8c7a-43fcf89e1a6b_setup', 'ClientSdkVersion': '1.20.0', 'FeaturizationRunJsonPath': 'featurizer_container.json', 'FeaturizationRunId': 'd4803e95-b194-4cd5-8c7a-43fcf89e1a6b_featurize', 'ProblemInfoJsonString': '{"dataset_num_categorical": 0, "is_sparse": true, "subsampling": false, "dataset_classes ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '93edac60-ce6d-4022-95b9-043379e050cb', 'status': 'Completed', 'startTimeUtc': '2021-02-09T18:05:49.723701Z', 'endTimeUtc': '2021-02-09T18:49:17.271404Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg138268.blob.core.windows.net/azureml/ExperimentRun/dcid.93edac60-ce6d-4022-95b9-043379e050cb/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=ixwvtmdL%2FH6RLxpAGIE55I0OFGT8wHeG5dUsstX2nl0%3D&st=2021-02-09T17%3A55%3A56Z&se=2021-02-10T02%3A05%3A56Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg138268.blob.core.windows.net/azureml/ExperimentRun/dcid.93edac60-ce6d-4022-95b9-043379e050cb/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=YJzL80oeeZB6Mt5PO04tyMGlmVyAu0MYvXmpRHUe9Ig%3D&st=2021-02-09T17%3A55%3A56Z&se=2021-02-10T02%3A05%3A56Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg138268.blob.core.windows.net/azureml/ExperimentRun/dcid.93edac60-ce6d-4022-95b9-043379e050cb/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=xCAPUPcCCoXiMCX6ksw1a5iUUntU6cxVMhVDf6D%2Bf2U%3D&st=2021-02-09T17%3A55%3A56Z&se=2021-02-10T02%3A05%3A56Z&sp=r'}, 'submittedBy': 'ODL_User 138268'}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/d4803e95-b194-4cd5-8c7a-43fcf89e1a6b/metrics_data
# Downloaded azureml/d4803e95-b194-4cd5-8c7a-43fcf89e1a6b/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  d4803e95-b194-4cd5-8c7a-43fcf89e1a6b_15  \
# balanced_accuracy                                                  [0.5]
# accuracy                                            [0.8880121396054628]
# precision_score_weighted                             [0.788565560086672]
# log_loss                                             [0.262298486854219]
# average_precision_score_micro                        [0.960713210598638]
# f1_score_micro                                      [0.8880121396054628]
# matthews_correlation                                               [0.0]
# AUC_micro                                           [0.9620945885267834]
# average_precision_score_macro                       [0.6927125188450116]
# norm_macro_recall                                                  [0.0]
# f1_score_weighted                                   [0.8353395018439429]
# AUC_macro                                            [0.872473589739315]
# recall_score_macro                                                 [0.5]
# AUC_weighted                                        [0.8724735897393149]
# precision_score_macro                               [0.4440060698027314]
# precision_score_micro                               [0.8880121396054628]
# average_precision_score_weighted                    [0.9154530802838067]
# weighted_accuracy                                   [0.9843450583187134]
# recall_score_micro                                  [0.8880121396054628]
# recall_score_weighted                               [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
#
#                                  d4803e95-b194-4cd5-8c7a-43fcf89e1a6b_14  \
# balanced_accuracy                                   [0.5008423683006481]
# accuracy                                            [0.8874051593323217]
# precision_score_weighted                            [0.8167114847178284]
# log_loss                                           [0.25147958268980775]
# average_precision_score_micro                       [0.9685936425397202]
# f1_score_micro                                      [0.8874051593323216]
# matthews_correlation                              [0.015257677052441887]
# AUC_micro                                           [0.9680344293211078]
# average_precision_score_macro                       [0.7461037335623407]
# norm_macro_recall                                [0.0016847366012961995]
# f1_score_weighted                                   [0.8356204112868567]
# AUC_macro                                           [0.9023408484255724]
# recall_score_macro                                  [0.5008423683006481]
# AUC_weighted                                        [0.9023408484255724]
# precision_score_macro                               [0.5690899422667882]
# precision_score_micro                               [0.8874051593323217]
# average_precision_score_weighted                     [0.932037174024255]
# weighted_accuracy                                   [0.9833782439989162]
# recall_score_micro                                  [0.8874051593323217]
# recall_score_weighted                               [0.8874051593323217]
# f1_score_macro                                     [0.47284342292451603]
#
#                                  d4803e95-b194-4cd5-8c7a-43fcf89e1a6b_21  \
# balanced_accuracy                                   [0.7411947273949842]
# accuracy                                            [0.9125948406676783]
# precision_score_weighted                            [0.9064419404986112]
# log_loss                                           [0.18386077817913915]
# average_precision_score_micro                       [0.9800107530929907]
# f1_score_micro                                      [0.9125948406676783]
# matthews_correlation                                [0.5264365575296669]
# AUC_micro                                           [0.9790159827392864]
# average_precision_score_macro                       [0.8131628841963428]
# norm_macro_recall                                   [0.4823894547899683]
# f1_score_weighted                                   [0.9087900123862012]
# AUC_macro                                           [0.9424512871239443]
# recall_score_macro                                  [0.7411947273949842]
# AUC_weighted                                        [0.9424512871239444]
# precision_score_macro                               [0.7872528061629692]
# precision_score_micro                               [0.9125948406676783]
# average_precision_score_weighted                    [0.9524536910133203]
# weighted_accuracy                                    [0.955148852498673]
# recall_score_micro                                  [0.9125948406676783]
# recall_score_weighted                               [0.9125948406676783]
# f1_score_macro                                      [0.7613817409356443]
#
#                                  d4803e95-b194-4cd5-8c7a-43fcf89e1a6b_25  \
# balanced_accuracy                                   [0.7159621151918969]
# accuracy                                            [0.9077389984825494]
# precision_score_weighted                            [0.8992110967163239]
# log_loss                                            [0.1880124255406952]
# average_precision_score_micro                       [0.9790992488308239]
# f1_score_micro                                      [0.9077389984825494]
# matthews_correlation                               [0.48767795941601105]
# AUC_micro                                           [0.9780497880404623]
# average_precision_score_macro                       [0.8072509489251203]
# norm_macro_recall                                   [0.4319242303837938]
# f1_score_weighted                                   [0.9021770532058848]
# AUC_macro                                           [0.9389373285393825]
# recall_score_macro                                  [0.7159621151918969]
# AUC_weighted                                        [0.9389373285393824]
# precision_score_macro                               [0.7753142511695126]
# precision_score_micro                               [0.9077389984825494]
# average_precision_score_weighted                     [0.950761405989792]
# weighted_accuracy                                   [0.9553520111267004]
# recall_score_micro                                  [0.9077389984825494]
# recall_score_weighted                               [0.9077389984825494]
# f1_score_macro                                      [0.7405646205646206]
#
#                                  d4803e95-b194-4cd5-8c7a-43fcf89e1a6b_30  \
# balanced_accuracy                                                  [0.5]
# accuracy                                            [0.8880121396054628]
# precision_score_weighted                             [0.788565560086672]
# log_loss                                            [0.2880940127519761]
# average_precision_score_micro                       [0.9709129059400662]
# f1_score_micro                                      [0.8880121396054628]
# matthews_correlation                                               [0.0]
# AUC_micro                                           [0.9695754592072875]
# average_precision_score_macro                       [0.7440177087576056]
# norm_macro_recall                                                  [0.0]
# f1_score_weighted                                   [0.8353395018439429]
# AUC_macro                                           [0.9100860984686403]
# recall_score_macro                                                 [0.5]
# AUC_weighted                                        [0.9100860984686403]
# precision_score_macro                               [0.4440060698027314]
# precision_score_micro                               [0.8880121396054628]
# average_precision_score_weighted                    [0.9333441512635487]
# weighted_accuracy                                   [0.9843450583187134]
# recall_score_micro                                  [0.8880121396054628]
# recall_score_weighted                               [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
#
#                                  d4803e95-b194-4cd5-8c7a-43fcf89e1a6b_9  \
# balanced_accuracy                                  [0.7364600525704506]
# accuracy                                           [0.7338391502276176]
# precision_score_weighted                           [0.8789778022732184]
# log_loss                                           [0.5542924510260777]
# average_precision_score_micro                      [0.7792779649678845]
# f1_score_micro                                     [0.7338391502276176]
# matthews_correlation                              [0.31973993897447045]
# AUC_micro                                          [0.8222996631213431]
# average_precision_score_macro                      [0.7064773264118134]
# norm_macro_recall                                  [0.4729201051409011]
# f1_score_weighted                                  [0.7802583050428904]
# AUC_macro                                          [0.8285755038001508]
# recall_score_macro                                 [0.7364600525704506]
# AUC_weighted                                       [0.8285755038001508]
# precision_score_macro                              [0.6080876319954074]
# precision_score_micro                              [0.7338391502276176]
# average_precision_score_weighted                   [0.9121967893447964]
# weighted_accuracy                                   [0.733188451070101]
# recall_score_micro                                 [0.7338391502276176]
# recall_score_weighted                              [0.7338391502276176]
# f1_score_macro                                     [0.6069827154623761]
#
#                                  d4803e95-b194-4cd5-8c7a-43fcf89e1a6b_29  \
# balanced_accuracy                                   [0.7289996054437646]
# accuracy                                            [0.9098634294385433]
# precision_score_weighted                            [0.9026804625146836]
# log_loss                                           [0.18279927212031324]
# average_precision_score_micro                       [0.9798553536942687]
# f1_score_micro                                      [0.9098634294385431]
# matthews_correlation                                [0.5066504244138683]
# AUC_micro                                           [0.9788629942364506]
# average_precision_score_macro                       [0.8089325091475965]
# norm_macro_recall                                  [0.45799921088752926]
# f1_score_weighted                                   [0.9053354992418561]
# AUC_macro                                           [0.9423457016525052]
# recall_score_macro                                  [0.7289996054437646]
# AUC_weighted                                        [0.9423457016525052]
# precision_score_macro                                [0.780234819685955]
# precision_score_micro                               [0.9098634294385433]
# average_precision_score_weighted                    [0.9514823604411914]
# weighted_accuracy                                    [0.954767024652788]
# recall_score_micro                                  [0.9098634294385433]
# recall_score_weighted                               [0.9098634294385433]
# f1_score_macro                                      [0.7509632657361396]
#
#                                  d4803e95-b194-4cd5-8c7a-43fcf89e1a6b_38  \
# balanced_accuracy                                   [0.7489950856446363]
# accuracy                                            [0.9159332321699545]
# precision_score_weighted                            [0.9100320532384002]
# log_loss                                           [0.17874635707235972]
# average_precision_score_micro                       [0.9810983099768911]
# f1_score_micro                                      [0.9159332321699545]
# matthews_correlation                                [0.5442698603413753]
# AUC_micro                                           [0.9801769821843461]
# average_precision_score_macro                       [0.8189983710386364]
# norm_macro_recall                                   [0.4979901712892727]
# f1_score_weighted                                   [0.9122119541016598]
# AUC_macro                                           [0.9463811042758412]
# recall_score_macro                                  [0.7489950856446363]
# AUC_weighted                                        [0.9463811042758411]
# precision_score_macro                               [0.7974252284026968]
# precision_score_micro                               [0.9159332321699545]
# average_precision_score_weighted                    [0.9541637785040213]
# weighted_accuracy                                    [0.957379458351734]
# recall_score_micro                                  [0.9159332321699545]
# recall_score_weighted                               [0.9159332321699545]
# f1_score_macro                                      [0.7701924314056957]
#
#                                  d4803e95-b194-4cd5-8c7a-43fcf89e1a6b_19  \
# balanced_accuracy                                   [0.6792540293823991]
# accuracy                                            [0.9077389984825494]
# precision_score_weighted                             [0.895092517403297]
# log_loss                                           [0.19994256312838007]
# average_precision_score_micro                       [0.9775048906893984]
# f1_score_micro                                      [0.9077389984825494]
# matthews_correlation                                [0.4538726815046628]
# AUC_micro                                           [0.9763877305247063]
# average_precision_score_macro                       [0.7953500733144905]
# norm_macro_recall                                   [0.3585080587647982]
# f1_score_weighted                                   [0.8971238918213456]
# AUC_macro                                           [0.9329981457709313]
# recall_score_macro                                  [0.6792540293823991]
# AUC_weighted                                        [0.9329981457709314]
# precision_score_macro                               [0.7873023436711378]
# precision_score_micro                               [0.9077389984825494]
# average_precision_score_weighted                    [0.9474347924918001]
# weighted_accuracy                                   [0.9644656358962787]
# recall_score_micro                                  [0.9077389984825494]
# recall_score_weighted                               [0.9077389984825494]
# f1_score_macro                                        [0.71617170693669]
#
#                                  d4803e95-b194-4cd5-8c7a-43fcf89e1a6b_31  ...  \
# balanced_accuracy                                   [0.5563858834077062]  ...
# accuracy                                            [0.8977238239757208]  ...
# precision_score_weighted                             [0.887865856922645]  ...
# log_loss                                           [0.23335725306951471]  ...
# average_precision_score_micro                       [0.9751124268973704]  ...
# f1_score_micro                                      [0.8977238239757208]  ...
# matthews_correlation                                [0.2801007896693575]  ...
# AUC_micro                                           [0.9739682832083374]  ...
# average_precision_score_macro                        [0.791634273995414]  ...
# norm_macro_recall                                  [0.11277176681541246]  ...
# f1_score_weighted                                   [0.8622543167013796]  ...
# AUC_macro                                           [0.9309952634727987]  ...
# recall_score_macro                                  [0.5563858834077062]  ...
# AUC_weighted                                        [0.9309952634727987]  ...
# precision_score_macro                                [0.847855028740558]  ...
# precision_score_micro                               [0.8977238239757208]  ...
# average_precision_score_weighted                    [0.9462601314145473]  ...
# weighted_accuracy                                   [0.9824688015836945]  ...
# recall_score_micro                                  [0.8977238239757208]  ...
# recall_score_weighted                               [0.8977238239757208]  ...
# f1_score_macro                                      [0.5743319989220441]  ...
#
#                                  d4803e95-b194-4cd5-8c7a-43fcf89e1a6b_27  \
# balanced_accuracy                                                  [0.5]
# accuracy                                            [0.8880121396054628]
# precision_score_weighted                             [0.788565560086672]
# log_loss                                            [0.2741738187506259]
# average_precision_score_micro                       [0.9688318926888022]
# f1_score_micro                                      [0.8880121396054628]
# matthews_correlation                                               [0.0]
# AUC_micro                                           [0.9677841766045487]
# average_precision_score_macro                       [0.7277523358032929]
# norm_macro_recall                                                  [0.0]
# f1_score_weighted                                   [0.8353395018439429]
# AUC_macro                                           [0.9010798429925516]
# recall_score_macro                                                 [0.5]
# AUC_weighted                                        [0.9010798429925517]
# precision_score_macro                               [0.4440060698027314]
# precision_score_micro                               [0.8880121396054628]
# average_precision_score_weighted                     [0.928476377825117]
# weighted_accuracy                                   [0.9843450583187134]
# recall_score_micro                                  [0.8880121396054628]
# recall_score_weighted                               [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
#
#                                  d4803e95-b194-4cd5-8c7a-43fcf89e1a6b_23  \
# balanced_accuracy                                   [0.7452477275968932]
# accuracy                                            [0.9113808801213961]
# precision_score_weighted                            [0.9061410923608069]
# log_loss                                            [0.1922233799340996]
# average_precision_score_micro                       [0.9794278430710546]
# f1_score_micro                                      [0.9113808801213961]
# matthews_correlation                                 [0.526043819840976]
# AUC_micro                                           [0.9783950023141699]
# average_precision_score_macro                       [0.8133385492316565]
# norm_macro_recall                                  [0.49049545519378634]
# f1_score_weighted                                   [0.9082878900933731]
# AUC_macro                                           [0.9407795171594915]
# recall_score_macro                                  [0.7452477275968932]
# AUC_weighted                                        [0.9407795171594916]
# precision_score_macro                               [0.7820842654735272]
# precision_score_micro                               [0.9113808801213961]
# average_precision_score_weighted                    [0.9523124162348777]
# weighted_accuracy                                   [0.9526272480674925]
# recall_score_micro                                  [0.9113808801213961]
# recall_score_weighted                               [0.9113808801213961]
# f1_score_macro                                      [0.7618290845071816]
#
#                                  d4803e95-b194-4cd5-8c7a-43fcf89e1a6b_35  \
# balanced_accuracy                                   [0.5783958232610351]
# accuracy                                            [0.9010622154779969]
# precision_score_weighted                            [0.8900063735304807]
# log_loss                                           [0.22294269962465907]
# average_precision_score_micro                        [0.975133191409921]
# f1_score_micro                                      [0.9010622154779969]
# matthews_correlation                                [0.3272916174194138]
# AUC_micro                                            [0.973913664194381]
# average_precision_score_macro                       [0.7897671955080175]
# norm_macro_recall                                  [0.15679164652207023]
# f1_score_weighted                                   [0.8710255708656842]
# AUC_macro                                           [0.9275452118841079]
# recall_score_macro                                  [0.5783958232610351]
# AUC_weighted                                        [0.9275452118841077]
# precision_score_macro                               [0.8415992025376737]
# precision_score_micro                               [0.9010622154779969]
# average_precision_score_weighted                    [0.9455347418570257]
# weighted_accuracy                                   [0.9811715526872414]
# recall_score_micro                                  [0.9010622154779969]
# recall_score_weighted                               [0.9010622154779969]
# f1_score_macro                                      [0.6079992000653962]
#
#                                  d4803e95-b194-4cd5-8c7a-43fcf89e1a6b_39  \
# balanced_accuracy                                   [0.7149729460384145]
# accuracy                                            [0.9122913505311078]
# precision_score_weighted                            [0.9030094637308903]
# log_loss                                           [0.20032609487648573]
# average_precision_score_micro                       [0.9806407990606363]
# f1_score_micro                                      [0.9122913505311078]
# matthews_correlation                                [0.5029190958619679]
# AUC_micro                                           [0.9796965559165609]
# average_precision_score_macro                       [0.8176846075283798]
# norm_macro_recall                                   [0.4299458920768291]
# f1_score_weighted                                   [0.9054936927070897]
# AUC_macro                                           [0.9445944869564895]
# recall_score_macro                                  [0.7149729460384145]
# AUC_weighted                                        [0.9445944869564894]
# precision_score_macro                               [0.7941388924090736]
# precision_score_micro                               [0.9122913505311078]
# average_precision_score_weighted                    [0.9536738980718532]
# weighted_accuracy                                   [0.9612801729941132]
# recall_score_micro                                  [0.9122913505311078]
# recall_score_weighted                               [0.9122913505311078]
# f1_score_macro                                      [0.7460293710922801]
#
#                                  d4803e95-b194-4cd5-8c7a-43fcf89e1a6b_3  \
# balanced_accuracy                                  [0.7980784370386425]
# accuracy                                           [0.8012139605462822]
# precision_score_weighted                           [0.8977876326370297]
# log_loss                                           [0.5072015031681759]
# average_precision_score_micro                       [0.865076963044239]
# f1_score_micro                                     [0.8012139605462822]
# matthews_correlation                               [0.4261632055062389]
# AUC_micro                                          [0.8729860159666206]
# average_precision_score_macro                      [0.7551819713108755]
# norm_macro_recall                                  [0.5961568740772849]
# f1_score_weighted                                  [0.8321532208226776]
# AUC_macro                                          [0.8952013255607607]
# recall_score_macro                                 [0.7980784370386425]
# AUC_weighted                                       [0.8952013255607607]
# precision_score_macro                              [0.6523215495992155]
# precision_score_micro                              [0.8012139605462822]
# average_precision_score_weighted                   [0.9340864612479511]
# weighted_accuracy                                  [0.8019924262187536]
# recall_score_micro                                 [0.8012139605462822]
# recall_score_weighted                              [0.8012139605462822]
# f1_score_macro                                     [0.6748735219623541]
#
#                                  d4803e95-b194-4cd5-8c7a-43fcf89e1a6b_10  \
# balanced_accuracy                                   [0.7946367211450651]
# accuracy                                            [0.7908952959028832]
# precision_score_weighted                            [0.8967633186300693]
# log_loss                                            [0.5354425643124521]
# average_precision_score_micro                       [0.8409937118415841]
# f1_score_micro                                      [0.7908952959028832]
# matthews_correlation                                [0.4156256335274893]
# AUC_micro                                           [0.8664470239315099]
# average_precision_score_macro                       [0.7212118576712432]
# norm_macro_recall                                   [0.5892734422901302]
# f1_score_weighted                                   [0.8244694245316859]
# AUC_macro                                            [0.882532921364757]
# recall_score_macro                                  [0.7946367211450651]
# AUC_weighted                                        [0.8825329213647569]
# precision_score_macro                               [0.6465742852535306]
# precision_score_micro                               [0.7908952959028832]
# average_precision_score_weighted                    [0.9245440928050882]
# weighted_accuracy                                   [0.7899664012190897]
# recall_score_micro                                  [0.7908952959028832]
# recall_score_weighted                               [0.7908952959028832]
# f1_score_macro                                      [0.6657835707352922]
#
#                                  d4803e95-b194-4cd5-8c7a-43fcf89e1a6b_33  \
# balanced_accuracy                                   [0.7411947273949842]
# accuracy                                            [0.9125948406676783]
# precision_score_weighted                            [0.9064419404986112]
# log_loss                                           [0.18336134731730297]
# average_precision_score_micro                       [0.9801965514804069]
# f1_score_micro                                      [0.9125948406676783]
# matthews_correlation                                [0.5264365575296669]
# AUC_micro                                            [0.979213090142097]
# average_precision_score_macro                       [0.8149276637285758]
# norm_macro_recall                                   [0.4823894547899683]
# f1_score_weighted                                   [0.9087900123862012]
# AUC_macro                                           [0.9431190689213795]
# recall_score_macro                                  [0.7411947273949842]
# AUC_weighted                                        [0.9431190689213795]
# precision_score_macro                               [0.7872528061629692]
# precision_score_micro                               [0.9125948406676783]
# average_precision_score_weighted                    [0.9529182178519179]
# weighted_accuracy                                    [0.955148852498673]
# recall_score_micro                                  [0.9125948406676783]
# recall_score_weighted                               [0.9125948406676783]
# f1_score_macro                                      [0.7613817409356443]
#
#                                  d4803e95-b194-4cd5-8c7a-43fcf89e1a6b_8  \
# balanced_accuracy                                                 [0.5]
# accuracy                                           [0.8880121396054628]
# precision_score_weighted                            [0.788565560086672]
# log_loss                                           [0.2737179161461082]
# average_precision_score_micro                      [0.9628637978410217]
# f1_score_micro                                     [0.8880121396054628]
# matthews_correlation                                              [0.0]
# AUC_micro                                          [0.9630956914992828]
# average_precision_score_macro                      [0.7316228200370556]
# norm_macro_recall                                                 [0.0]
# f1_score_weighted                                  [0.8353395018439429]
# AUC_macro                                            [0.87750696030542]
# recall_score_macro                                                [0.5]
# AUC_weighted                                         [0.87750696030542]
# precision_score_macro                              [0.4440060698027314]
# precision_score_micro                              [0.8880121396054628]
# average_precision_score_weighted                   [0.9249895533315703]
# weighted_accuracy                                  [0.9843450583187134]
# recall_score_micro                                 [0.8880121396054628]
# recall_score_weighted                              [0.8880121396054628]
# f1_score_macro                                     [0.4703423886834914]
#
#                                  d4803e95-b194-4cd5-8c7a-43fcf89e1a6b_26  \
# balanced_accuracy                                   [0.7401814773445069]
# accuracy                                            [0.9128983308042489]
# precision_score_weighted                            [0.9065343959710289]
# log_loss                                           [0.18354087685416373]
# average_precision_score_micro                       [0.9798597961315479]
# f1_score_micro                                      [0.9128983308042489]
# matthews_correlation                                [0.5265756963424171]
# AUC_micro                                           [0.9788788365136859]
# average_precision_score_macro                       [0.8078135890376441]
# norm_macro_recall                                   [0.4803629546890138]
# f1_score_weighted                                    [0.908914057592548]
# AUC_macro                                           [0.9428782599514307]
# recall_score_macro                                  [0.7401814773445069]
# AUC_weighted                                        [0.9428782599514307]
# precision_score_macro                               [0.7886171396772399]
# precision_score_micro                               [0.9128983308042489]
# average_precision_score_weighted                    [0.9512932336269386]
# weighted_accuracy                                    [0.955779253606468]
# recall_score_micro                                  [0.9128983308042489]
# recall_score_weighted                               [0.9128983308042489]
# f1_score_macro                                      [0.7612649763995245]
#
#                                  d4803e95-b194-4cd5-8c7a-43fcf89e1a6b_24
# balanced_accuracy                                   [0.7459312545962097]
# accuracy                                            [0.9125948406676783]
# precision_score_weighted                            [0.9071064203941039]
# log_loss                                           [0.18420134724861562]
# average_precision_score_micro                       [0.9800058297942514]
# f1_score_micro                                      [0.9125948406676783]
# matthews_correlation                                 [0.530535514228425]
# AUC_micro                                           [0.9790132195513965]
# average_precision_score_macro                       [0.8130064306176901]
# norm_macro_recall                                  [0.49186250919241936]
# f1_score_weighted                                   [0.9092961593409308]
# AUC_macro                                           [0.9423114326837048]
# recall_score_macro                                  [0.7459312545962097]
# AUC_weighted                                        [0.9423114326837048]
# precision_score_macro                               [0.7861246045360897]
# precision_score_micro                               [0.9125948406676783]
# average_precision_score_weighted                    [0.9524012051949555]
# weighted_accuracy                                   [0.9539729009155015]
# recall_score_micro                                  [0.9125948406676783]
# recall_score_weighted                               [0.9125948406676783]
# f1_score_macro                                      [0.7638698118841445]
#
# [21 rows x 37 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/d4803e95-b194-4cd5-8c7a-43fcf89e1a6b/model_data
# Downloaded azureml/d4803e95-b194-4cd5-8c7a-43fcf89e1a6b/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                                                                                    n_jobs=1,
#                                                                                                                                    oob_score=True,
#                                                                                                                                    random_state=None,
#                                                                                                                                    verbose=0,
#                                                                                                                                    warm_start=False))],
#                                                                                                       verbose=False))],
#                                                                                 flatten_transform=None,
#                                                                                 weights=[0.2857142857142857,
#                                                                                          0.21428571428571427,
#                                                                                          0.07142857142857142,
#                                                                                          0.07142857142857142,
#                                                                                          0.07142857142857142,
#                                                                                          0.07142857142857142,
#                                                                                          0.14285714285714285,
#                                                                                          0.07142857142857142]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#                   feature_sweeping_config=None, feature_sweeping_timeout=None,
#                   featurization_config=None, force_text_dnn=None,
#                   is_cross_validation=None, is_onnx_compatible=None, logger=None,
#                   observer=None, task=None, working_dir=None)),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(classification_labels=None,
#                                 estimators=[('0',
#                                              Pipeline(memory=None,
#                                                       steps=[('maxabsscaler',
#                                                               MaxAbsScaler(copy=True)),
#                                                              ('lightgbmclassifier',
#                                                               LightGBMClassifier(boosting_type='gbdt',
#                                                                                  class_weight=None,
#                                                                                  colsample_bytree=1.0,
#                                                                                  importance_type='split',
#                                                                                  learning_rate=0.1,
#                                                                                  max_depth=-1,
#                                                                                  min_child_samples=20,
#                                                                                  min_child_weight=0.001,
#                                                                                  min_spl...
#                                                                                    min_samples_split=0.056842105263157895,
#                                                                                    min_weight_fraction_leaf=0.0,
#                                                                                    n_estimators=25,
#                                                                                    n_jobs=1,
#                                                                                    oob_score=True,
#                                                                                    random_state=None,
#                                                                                    verbose=0,
#                                                                                    warm_start=False))],
#                                                       verbose=False))],
#                                 flatten_transform=None,
#                                 weights=[0.2857142857142857, 0.21428571428571427,
#                                          0.07142857142857142, 0.07142857142857142,
#                                          0.07142857142857142, 0.07142857142857142,
#                                          0.14285714285714285,
#                                          0.07142857142857142]))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_1add8aea_6b08_11eb_8345_4d051fec4d48row0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_1add8aea_6b08_11eb_8345_4d051fec4d48row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1add8aea_6b08_11eb_8345_4d051fec4d48row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1add8aea_6b08_11eb_8345_4d051fec4d48row1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_1add8aea_6b08_11eb_8345_4d051fec4d48" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1add8aea_6b08_11eb_8345_4d051fec4d48level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1add8aea_6b08_11eb_8345_4d051fec4d48row0_col0" class="data row0 col0" >28836</td>
#                         <td id="T_1add8aea_6b08_11eb_8345_4d051fec4d48row0_col1" class="data row0 col1" >422</td>
#             </tr>
#             <tr>
#                         <th id="T_1add8aea_6b08_11eb_8345_4d051fec4d48level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_1add8aea_6b08_11eb_8345_4d051fec4d48row1_col0" class="data row1 col0" >1079</td>
#                         <td id="T_1add8aea_6b08_11eb_8345_4d051fec4d48row1_col1" class="data row1 col1" >2613</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: 5939ee3a-5bf8-4db8-94f5-cc34cfa74da1,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/b968fb36-f06a-4c76-a15f-afab68ae7667/resourceGroups/aml-quickstarts-138268/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-138268/PipelineRuns/PipelineSubmit/5939ee3a-5bf8-4db8-94f5-cc34cfa74da1)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  2ed9eeba-1fc4-4357-a391-b0f56019975c

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
